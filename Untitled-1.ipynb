# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'untitled1.ui'
#
# Created by: PyQt5 UI code generator 5.15.9
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
import pandas as pd
from PyQt5 import QtCore, QtGui, QtWidgets
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
from PyQt5 import QtCore, QtWidgets
from PyQt5.QtWidgets import QFileDialog
from matplotlib.backends.backend_qt5agg import FigureCanvasQTAgg, NavigationToolbar2QT as Navi
from matplotlib.figure import Figure
import seaborn as sns
import pandas as pd
import sip as sip

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(800, 600)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.pushButton = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton.setGeometry(QtCore.QRect(10, 170, 75, 23))
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_2.setGeometry(QtCore.QRect(140, 170, 75, 23))
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton_3 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_3.setGeometry(QtCore.QRect(280, 170, 75, 23))
        self.pushButton_3.setObjectName("pushButton_3")
        self.pushButton_4 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_4.setGeometry(QtCore.QRect(10, 170, 75, 23))
        self.pushButton_4.setObjectName("pushButton_4")
        self.label = QtWidgets.QLabel(self.centralwidget)
        self.label.setGeometry(QtCore.QRect(20, 20, 71, 31))
        self.label.setObjectName("label")
        self.calendarWidget = QtWidgets.QCalendarWidget(self.centralwidget)
        self.calendarWidget.setGeometry(QtCore.QRect(591, 482, 171, 61))
        self.calendarWidget.setObjectName("calendarWidget")
        self.lcdNumber = QtWidgets.QLCDNumber(self.centralwidget)
        self.lcdNumber.setGeometry(QtCore.QRect(50, 440, 81, 51))
        self.lcdNumber.setObjectName("lcdNumber")
        self.progressBar = QtWidgets.QProgressBar(self.centralwidget)
        self.progressBar.setGeometry(QtCore.QRect(50, 360, 118, 31))
        self.progressBar.setProperty("value", 24)
        self.progressBar.setObjectName("progressBar")
        self.openGLWidget = QtWidgets.QOpenGLWidget(self.centralwidget)
        self.openGLWidget.setGeometry(QtCore.QRect(449, 10, 301, 191))
        self.openGLWidget.setObjectName("openGLWidget")
        self.dial = QtWidgets.QDial(self.centralwidget)
        self.dial.setGeometry(QtCore.QRect(629, 230, 121, 111))
        self.dial.setObjectName("dial")
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 800, 21))
        self.menubar.setObjectName("menubar")
        self.menuData_Visual = QtWidgets.QMenu(self.menubar)
        self.menuData_Visual.setObjectName("menuData_Visual")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)
        self.menubar.addAction(self.menuData_Visual.menuAction())

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        self.pushButton_4.clicked.connect(self.load_data)
        self.pushButton_3.clicked.connect(self.create_pie_chart)
        self.pushButton_2.clicked.connect(self.create_bar_chart)
        #self.pushButton_2.clicked.connect(self.create_create_pie_chart)
    def load_data(self):
        file_dialog = QtWidgets.QFileDialog()
        file_dialog.setFileMode(QtWidgets.QFileDialog.ExistingFile)
        file_dialog.setNameFilter("CSV Files (*.csv)")

        if file_dialog.exec_():
            file_paths = file_dialog.selectedFiles()
            if file_paths:
                csv_file_path = file_paths[0]
                self.data = pd.read_csv(csv_file_path)
                print("Data Loaded:", csv_file_path)
    def create_pie_chart(self):
        if self.data is not None:
            column_name = QtWidgets.QInputDialog.getText(None, 'Input Dialog', 'Enter column name for Pie Chart:')
            if column_name[1]:
                try:
                    counts = self.data[column_name[0]].value_counts()
                    plt.figure(figsize=(8, 8))
                    plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
                    plt.title('Pie Chart for ' + column_name[0])
                    plt.axis('equal')
                    plt.show()
                except KeyError:
                    print("Invalid column name!")
        else:
            print("No data loaded. Please load data first.")

    def create_bar_chart(self):
        if self.data is not None:
           column_name, ok_pressed = QtWidgets.QInputDialog.getText(None, 'Input Dialog', 'Enter column name for Bar Chart:')
           if ok_pressed and column_name:
               try:
                if column_name in self.data.columns:
                    plt.figure(figsize=(10, 6))
                    self.data[column_name].plot(kind='bar')
                    plt.title(f'Bar Chart for Column: {column_name}')
                    plt.xlabel('Data Points')
                    plt.ylabel('Values')
                    plt.show()
                else:
                    print("Column name not found in the dataset!")
               except Exception as e:
                  print(f"Error creating bar chart: {e}")
        else:
          print("No data loaded. Please load data first.")
    
    def generate_heatmap(self):
        if self.data is not None:
            plt.figure(figsize=(8, 6))
            sns.heatmap(self.data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
            plt.title('Correlation Heatmap')
            plt.show()
        else:
            print("No data loaded. Please load data first.")


    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.pushButton.setText(_translate("MainWindow", "Pie_chart"))
        self.pushButton_2.setText(_translate("MainWindow", "bar_chart"))
        self.pushButton_3.setText(_translate("MainWindow", "Heat_map"))
        self.pushButton_4.setText(_translate("MainWindow", "Load_Data"))
        self.label.setText(_translate("MainWindow", "Load filles"))
        self.menuData_Visual.setTitle(_translate("MainWindow", "Data_Visual"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 92, in Ui_MainWindow.create_pie_chart(self)
#      91 def create_pie_chart(self):
# ---> 92     if self.data is not None:
#      93         column_name = QtWidgets.QInputDialog.getText(None, 'Input Dialog', 'Enter column name for Pie Chart:')
#      94         if column_name[1]:
#
# AttributeError: 'Ui_MainWindow' object has no attribute 'data'
# Data Loaded: F:/Sensor_data/iot_telemetry_data.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\Carrington\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backends\backend_qt.py:790, in NavigationToolbar2QT.save_figure(self, *args)
#     788     mpl.rcParams['savefig.directory'] = os.path.dirname(fname)
#     789 try:
# ...

# %%
    def create_bar_chart(self):
        if self.data is not None:
            plt.figure(figsize=(10, 6))
            self.data.plot(kind='bar')
            plt.title('Bar Chart for All Columns')
            plt.xlabel('Data Points')
            plt.ylabel('Values')
            plt.show()
        else:
            print("No data loaded. Please load data first.")
